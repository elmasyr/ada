# %% [markdown]
# # Example report | TKO_2096 Application of Data Analysis 2019
# ## Exercise 3 | Pain assessment from biosignal data

# %% [markdown]
# Elise Syrjälä (123456)

# %% [markdown]
# ### Import libraries

# %%
'''Import needed libraries'''
import pandas as pd
import numpy as np

import sklearn
from sklearn.neighbors import NearestNeighbors

'''Plotting inline'''
# %matplotlib inline

# %% [markdown]
# ### Import data

# %%
'''Read the file'''
df = pd.read_csv('paindata.csv', header=0, sep=',')
df.shape
# Out:
# (10300, 8)

# %% [markdown]
# #### View and check data

# %%
df.head(2)
# Out:
#    subject  test  label  label_time  feat1     feat2     feat3       feat4
# 0        1     1      1           1    1.2  5.962879  5.939946  423.315903
# 1        1     1      1           2    1.2  5.951589  5.950951  425.578340

# %%
df.sample(6)
# Out:
#       subject  test  label  label_time     feat1     feat2     feat3  \
# 9750       29     4      3          29  0.802768  6.021571  6.032660
# 5743       18     4      2          41  0.841616  5.884101  5.952620
# 1467        5     4      1           2  0.840000  5.983100  5.975467
# 450         2     2      3           8  0.910880  5.938540  5.920900
# 5237       17     3      2          73  0.850176  5.939546  5.929900
# 1124        4     3      2          45  0.593488  5.926716  5.937239
#
#            feat4
# 9750  426.265278
# 5743  932.974791
# 1467  788.101480
# 450   737.348455
# 5237  749.267664
# 1124  551.260598

# %%
df.tail(2)
# Out:
#        subject  test  label  label_time     feat1     feat2     feat3  \
# 10298       31     4      3          16  0.691872  5.946948  5.975803
# 10299       31     4      3          17  0.689360  5.937598  5.964758
#
#             feat4
# 10298  542.284997
# 10299  545.280563

# %%
len(df.subject.unique())
# Out:
# 31

# %% [markdown]
# ### Standardization of the data

# %%
# Define feature columns
####
# Out:
# ['feat1', 'feat2', 'feat3', 'feat4']

# %%
# features and standardization function
zscore = lambda x: (x - x.mean()) / x.std()
# dfs = standardise(df, featcols, groupby, zscore)

# new subject level standardized dataframe
dfs = df.copy()
dfs[featcols] =####

# %%
'''Any missing values?'''
dfs.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### KNN and LSO CV

# %%
####

# %% [markdown]
# ### Results for data z-score standardized on subject level

# %%
'''setup parameters'''
####

print ('Analysis results (z-score standardization on subject level)')
print ('subject, c-index')
'''call the function and store the output as myperf'''
myperf = lso_knn(data, k, xcols, ycol)
# Out:
# Analysis results (z-score standardization on subject level)
# subject, c-index
# 1 0.764
# 2 0.572
# 3 0.519
# 4 0.687
# 5 0.593
# 6 0.488
# 7 0.664
# 8 0.670
# 9 0.530
# 10 0.579
# 11 0.658
# 12 0.638
# 13 0.653
# 14 0.559
# 15 0.789
# 16 0.685
# 17 0.702
# 18 0.711
# 19 0.648
# 20 0.515
# 21 0.661
# 22 0.518
# 23 0.667
# 24 0.505
# 25 0.606
# 26 0.569
# 27 0.687
# 28 0.816
# 29 0.633
# 30 0.641
# 31 0.557

# %%
'''stats of the performance'''
print ('C-index min','%.3f' % ####)
print ('C-index max','%.3f' % ####)
print ('C-index average','%.3f' % ####)
print ('C-index std','%.3f' % ####)
# Out:
# C-index min 0.488
# C-index max 0.816
# C-index average 0.628
# C-index std 0.083

# %% [markdown]
# ### Interpretation

# %% [markdown]
# bla, bla, bla, bla

# %% [markdown]
# ### Extra work

# %%
'''quick plot of the performance'''
####

# %%
dfs[featcols].plot(figsize=(15,5));

# %%
dfs[featcols].plot(figsize=(10,3), subplots=True);

# %% [markdown]
# ## Used versions

# %%
# by github/jrjohansson
# ! pip install --user version_information
# %load_ext version_information
# %version_information pandas, numpy, sklearn, matplotlib
# Out:
# Software versions
# Python 3.6.8 64bit [GCC 7.3.0]
# IPython 7.2.0
# OS Linux 4.4.0 43 Microsoft x86_64 with debian stretch sid
# pandas 0.24.1
# numpy 1.15.4
# sklearn 0.20.2
# matplotlib 3.0.2
# Thu Feb 14 10:36:19 2019 STD

# %%
# !jupyter --version
# Out:
# 4.4.0

# %% [markdown]
# ## Tips

# %% [markdown]
# Before submitting your work, check
# - Instructions, including slides and video vs. methods and algorithms used.
# - Remove all irrelevant code and text, including library imports and functions.
# - Does my code run in a feasible time? i.e. can the customer check and run the code.
# - Are all reported items clearly in the jupyter notebook?
# - Before submitting, with the jupyter notebook:
#     - Kernel -> Restart and run all
#     - If not error messages, save the file.
# - Is the correct version submitted?
